# %%
#!pip install --upgrade google-api-python-client
#!pip install --upgrade google-auth-oauthlib google-auth-httplib2

# %%
import os
import pprint
pp = pprint.PrettyPrinter(indent=2)
import pandas as pd
import seaborn as sns

import google_auth_oauthlib.flow
import googleapiclient.discovery
import googleapiclient.errors

# %%
api_service_name = "youtube"
api_version = "v3"
api_key = "AIzaSyAa882vyHBXWNv2q3Uv8i3hQ2VbOeZfi7Q"
channel_ids = ["UCAmRvnP-GzdDp2Vo66g9ZPw",  #my channel ID
               "UCoOae5nYA7VqaXzerajD0lg"] #Ali Abdaal's channel ID

# %%
youtube = googleapiclient.discovery.build(
            api_service_name,
            api_version,
            developerKey=api_key
)

# %% [markdown]
# ## Example channel details

# %%
def get_channel_example(youtube, channel_id):
    all_data = []
    request = youtube.channels().list(
            part="snippet,contentDetails,statistics",
            id=channel_id  
    )
    response = request.execute()
    return response
example = get_channel_example(youtube, channel_id = "UC_x5XG1OV2P6uZZ5FSM9Ttw")
pp.pprint(example)
# Out:
# { 'etag': 'q-1EplXyocggcQkYCKksvbIfyU8',
#   'items': [ { 'contentDetails': { 'relatedPlaylists': { 'likes': '',
#                                                          'uploads': 'UU_x5XG1OV2P6uZZ5FSM9Ttw'}},
#                'etag': 'cyXwy_fL63OX0jLfCHWthcVR-bI',
#                'id': 'UC_x5XG1OV2P6uZZ5FSM9Ttw',
#                'kind': 'youtube#channel',
#                'snippet': { 'country': 'US',
#                             'customUrl': '@googledevelopers',
#                             'description': 'Subscribe to join a community of '
#                                            'creative developers and learn the '
#                                            'latest in Google technology — from '
#                                            'AI and cloud, to mobile and web.\n'
#                                            '\n'
#                                            'Explore more at '
#                                            'developers.google.com\n'
# ...

# %% [markdown]
# ## Get channel stats

# %%
def get_channel_stats(youtube, channel_ids):
    all_data = []
    request = youtube.channels().list(
            part="snippet,contentDetails,statistics",
            id=",".join(channel_ids)    
    )
    response = request.execute()
    for i in range(len(response['items'])):
        data = dict(
            channel_name = response['items'][i]['snippet']['title'],
            subscribers = response['items'][i]['statistics']['subscriberCount'],
            views = response['items'][i]['statistics']['viewCount'],
            video_count = response['items'][i]['statistics']['videoCount'],
            playlist_id = response['items'][i]['contentDetails']['relatedPlaylists']['uploads']
        )
        all_data.append(data)
    return all_data

# %%
data = get_channel_stats(youtube, channel_ids = channel_ids)

# %%
data
# Out:
# [{'channel_name': 'Gregvth',
#   'subscribers': '0',
#   'views': '5',
#   'video_count': '1',
#   'playlist_id': 'UUAmRvnP-GzdDp2Vo66g9ZPw'},
#  {'channel_name': 'Ali Abdaal',
#   'subscribers': '4750000',
#   'views': '360258115',
#   'video_count': '708',
#   'playlist_id': 'UUoOae5nYA7VqaXzerajD0lg'}]

# %% [markdown]
# ## Load into DF and clean

# %%
stats_df = pd.DataFrame(data=data)

# %%
stats_df.head()
# Out:
#   channel_name subscribers      views video_count               playlist_id
# 0      Gregvth           0          5           1  UUAmRvnP-GzdDp2Vo66g9ZPw
# 1   Ali Abdaal     4750000  360258115         708  UUoOae5nYA7VqaXzerajD0lg

# %%
stats_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   channel_name  2 non-null      object
#  1   subscribers   2 non-null      object
#  2   views         2 non-null      object
#  3   video_count   2 non-null      object
#  4   playlist_id   2 non-null      object
# dtypes: object(5)
# memory usage: 208.0+ bytes

# %%
stats_df['subscribers'] = pd.to_numeric(stats_df['subscribers'])
stats_df['views'] = pd.to_numeric(stats_df['views'])
stats_df['video_count'] = pd.to_numeric(stats_df['video_count'])
stats_df.dtypes
# Out:
# channel_name    object
# subscribers      int64
# views            int64
# video_count      int64
# dtype: object

# %% [markdown]
# ## Get video IDs

# %%
def get_video_ids(youtube, playlist_id):
    request = youtube.playlistItems().list(
        part="contentDetails",
        playlistId=playlist_id,
        maxResults=50,
    )
    response = request.execute()
    
    video_ids = []
    
    for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])
    
    next_page_token = response.get('nextPageToken')
    more_pages = True
    
    while more_pages:
        if next_page_token is None:
            more_pages = False
        else:
            request = youtube.playlistItems().list(
            part="contentDetails",
            playlistId=playlist_id,
            maxResults=50,
            pageToken=next_page_token
            )
            response = request.execute()
            
            for i in range(len(response['items'])):
                video_ids.append(response['items'][i]['contentDetails']['videoId'])
            
            next_page_token = response.get('nextPageToken')
            
    video_count = len(video_ids) + 1
    print(str(video_count) + " videos found in playlist ID: " + playlist_id)
    return video_ids

# %%
video_ids = get_video_ids(youtube, playlist_id="UUoOae5nYA7VqaXzerajD0lg")
# Out:
# 706 videos found in playlist ID: UUoOae5nYA7VqaXzerajD0lg

# %%
video_ids
# Out:
# ['E8vwGLMTx5I',
#  '0E9ZcyCpMIs',
#  'hBEKGBLAB80',
#  'V9SmqAoawH8',
#  'iBM0PToZ2VM',
#  'SjcvBFfMulY',
#  'Pr0mI_gkS4k',
#  '1K-yiSBN8p4',
#  'pNcTkGQOKO8',
#  'I2rvAysA-_8',
#  '-ZscZv-IMyI',
#  'gY8MWe0CGqc',
#  'EgNHc43z374',
#  'b2lBUkZV4Xs',
#  'XEJBS5SJTpA',
#  'P7KXFybHaPk',
#  'nQyuCT_zzok',
#  'BgVIAGA4wmQ',
#  'Y-d90cILIDk',
#  'OksWjaMxUOQ',
#  'vBqOMLd1ZQk',
#  '0EJF8dRNLyQ',
#  'Nwvefe71xQM',
#  'LXYjFsuVOoc',
#  'hoGIdhIsdoU',
#  'Wg_ygTcS-uQ',
#  'rAaMMjf7mzw',
#  'z2ZJiIt4pmo',
#  'akoe4kn00xw',
#  'mBTPvvgRICQ',
#  'wTbKYgUzHkA',
#  'pN-QzM_pflM',
#  'Fq1O5Tp7ohc',
#  'poc4ctbnDYA',
#  'WlYFPeBpU4s',
#  'rjcejdY_iNU',
#  'NL2Vq32jyeo',
#  'XU7Kp2vG3NU',
#  'T2_uib0J8Hc',
#  'hJZ5v7dpKKM',
#  'XB7TLFKnXHw',
#  'rd206umLpk8',
#  'CcK2Xe9BcUk',
#  'tM2iMYMpRbU',
#  'HSJmimPjL5M',
#  'Ny3u3Z85KdQ',
#  '8ZvbInUxCXU',
#  'MiPtCN_fJbA',
#  'hI43prriJNQ',
#  'pzDSMirut2k',
#  '15lyO5qmtg0',
#  'alLf0hN5JsQ',
#  'Jcoam1CeAq4',
#  'OlQdgKmxSEI',
#  'cqyHd3lR7C8',
# ...

# %% [markdown]
# ## Get video details

# %%
def get_video_details(youtube, video_ids):
    all_video_stats = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
            part="snippet,statistics",
            id=",".join(video_ids[i:i+50])
        )
        response = request.execute()
        
        #print example video data
        pp.pprint(response['items'][0]['snippet'])
        
        for video in response['items']:
            video_stats = dict(title=video['snippet']['title'],
                               published_date=video['snippet']['publishedAt'],
                               views=video['statistics']['viewCount'],
                               likes=video['statistics']['likeCount'],
                               #dislikes=video['statistics']['dislikeCount'],
                               comments=video['statistics']['commentCount'],
                              )
            all_video_stats.append(video_stats)
        
    return all_video_stats

# %%
video_details = get_video_details(youtube, video_ids)
# Out:
# { 'categoryId': '27',
#   'channelId': 'UCoOae5nYA7VqaXzerajD0lg',
#   'channelTitle': 'Ali Abdaal',
#   'defaultAudioLanguage': 'en-GB',
#   'description': 'Check out Rize using this link: https://rize.io/aliabdaal or '
#                  'use the code ALIABDAAL to get 25% off your first 3 months\n'
#                  '\n'
#                  'Journalling has been one of the most important habits I’ve '
#                  'ever developed and has had a dramatic impact on my life. In '
#                  'this video, I go through why I think journaling is so '
#                  'powerful and share the best prompts you can use to get '
#                  'started as well. Enjoy x\n'
#                  '\n'
#                  '📖 Check out my new book Feel-Good Productivity here! '
#                  'https://www.feelgoodproductivity.com/?utm_campaign=preorder&utm_source=youtube_long&utm_medium=video_description&utm_content=Change+Your+Life+by+Journalling+%28my+ultimate+guide%29\n'
# ...

# %%
video_data = pd.DataFrame(video_details)

# %%
video_data
# Out:
#                                                  title        published_date  \
# 0    Change Your Life by Journaling (My Ultimate Gu...  2023-09-29T13:00:11Z
# 1    The Feel-Good Business Model: How to Make Mone...  2023-09-27T13:00:00Z
# 2                8 Simple Hacks to Improve Your Health  2023-09-22T13:30:28Z
# 3                     Why you should work for free 🧑‍💻  2023-09-22T12:00:26Z
# 4                        The Problem with Discipline 😓  2023-09-20T12:00:39Z
# ..                                                 ...                   ...
# 700  Payphone (Maroon 5) - Katherine Macfarland & A...  2017-01-04T23:13:51Z
# 701            6med UKCAT Crash Course - In a Nutshell  2016-05-09T18:45:18Z
# 702             6med BMAT Crash Course - In a Nutshell  2016-04-27T09:04:49Z
# 703  Rolling in the Deep (Adele) - Duranka Perera &...  2016-04-05T09:05:29Z
# 704           All of Me (John Legend) - Duranka Perera  2016-03-27T19:30:11Z
#
#       views likes comments
# ...

# %%
video_data['published_date'] = pd.to_datetime(video_data['published_date']).dt.date
video_data['views'] = pd.to_numeric(video_data['views'])
video_data['likes'] = pd.to_numeric(video_data['likes'])
video_data['comments'] = pd.to_numeric(video_data['comments'])
video_data.dtypes
# Out:
# title             object
# published_date    object
# views              int64
# likes              int64
# comments           int64
# dtype: object

# %%
video_data
# Out:
#                                                  title published_date   views  \
# 0    Change Your Life by Journaling (My Ultimate Gu...     2023-09-29   23391
# 1    The Feel-Good Business Model: How to Make Mone...     2023-09-27   76971
# 2                8 Simple Hacks to Improve Your Health     2023-09-22  203549
# 3                     Why you should work for free 🧑‍💻     2023-09-22   35262
# 4                        The Problem with Discipline 😓     2023-09-20   70407
# ..                                                 ...            ...     ...
# 700  Payphone (Maroon 5) - Katherine Macfarland & A...     2017-01-04   86743
# 701            6med UKCAT Crash Course - In a Nutshell     2016-05-09   15683
# 702             6med BMAT Crash Course - In a Nutshell     2016-04-27   38724
# 703  Rolling in the Deep (Adele) - Duranka Perera &...     2016-04-05   57493
# 704           All of Me (John Legend) - Duranka Perera     2016-03-27  119637
#
#      likes  comments
# ...

# %%
top10_videos = video_data.sort_values(by='views', ascending=False).head(10)
top10_videos
# Out:
#                                                  title published_date  \
# 343  9 Passive Income Ideas - How I Make $27k per Week     2021-04-15
# 418      How I Type REALLY Fast (156 Words per Minute)     2020-08-18
# 403                        How to Invest for Beginners     2020-10-11
# 537  How I ranked 1st at Cambridge University - The...     2019-04-09
# 596  How I take notes on my iPad Pro in medical sch...     2018-06-02
# 251                 My Evidence-Based Skincare Routine     2022-06-28
# 187  Why You're Always Tired - 7 Myths Ruining Your...     2022-12-09
# 616  How to study for exams - Evidence-based revisi...     2018-04-04
# 342     How I Manage My Time - 10 Time Management Tips     2021-04-18
# 202       What happened to these two brothers? #shorts     2022-11-22
#
#         views   likes  comments
# 343  13003639  396292     17894
# 418  10047529  322308     13332
# 403   8829549  312685     22640
# 537   8681647  305692      6301
# ...

# %%
ax1 = sns.barplot(x="views", y="title", data=top10_videos)

# %%
#video_data.to_csv("video_details_ali_abdaal.csv")
